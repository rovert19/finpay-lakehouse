-- %%
REFRESH MATERIALIZED VIEW IF EXISTS fintech_finpay.gold.dim_date;

REFRESH MATERIALIZED VIEW IF EXISTS fintech_finpay.gold.dim_user;

REFRESH MATERIALIZED VIEW IF EXISTS fintech_finpay.gold.dim_merchant;

REFRESH MATERIALIZED VIEW IF EXISTS fintech_finpay.gold.dim_channel;

REFRESH MATERIALIZED VIEW IF EXISTS fintech_finpay.gold.fact_transaction;
